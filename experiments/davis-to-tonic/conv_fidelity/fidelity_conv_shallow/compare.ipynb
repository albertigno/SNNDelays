# %%
import numpy as np
import matplotlib.pyplot as plt

p_i = np.load('spikes_input_B.npy')
p_0 = np.load('spikes_l0_B.npy')
p_1 = np.load('spikes_l1_B.npy')
p_3 = np.load('spikes_l3_B.npy')
p_4 = np.load('spikes_l4_B.npy')
p_5 = np.load('spikes_output_B.npy')

l_i = np.load('B_i.npy')
l_0 = np.load('B0.npy')
l_1 = np.load('B1.npy')
l_3 = np.load('B3.npy')
l_4 = np.load('B4.npy')
l_5 = np.load('B5.npy')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
data = p_i
sum_data = int(np.sum(data))
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} pytorch spikes')
plt.subplot(212)
data = l_i
sum_data = int(np.sum(data))
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} loihi spikes')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
data = p_0
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} pytorch spikes')
plt.subplot(212)
data = l_0
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} loihi spikes')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
data = p_1
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} pytorch spikes')
plt.subplot(212)
data = l_1
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} loihi spikes')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
data = p_3
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} pytorch spikes')
plt.subplot(212)
data = l_3
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} loihi spikes')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
data = p_4
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} pytorch spikes')
plt.subplot(212)
data = l_4
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} loihi spikes')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
data = p_5
sum_data = int(np.sum(data))
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} pytorch spikes')
plt.subplot(212)
data = l_5
sum_data = np.sum(data)
plt.imshow(data, aspect='auto', interpolation='none')
plt.title(f'{sum_data} loihi spikes')
plt.tight_layout()
