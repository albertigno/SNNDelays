# %%
import dv_processing as dv
import torch
from snn_delays.utils.dataset_loader import DatasetLoader
from snn_delays.utils.model_loader_refac import ModelLoader
from snn_delays.utils.train_utils_refact_minimal import get_device
from snn_delays.utils.hw_aware_utils import quantize_weights
from snn_delays.utils.hw_aware_utils import save_weights_delays, save_state
import numpy as np
import os
device = get_device() 

# For reproducibility
torch.manual_seed(10)
# Out:
# Running on: cuda:0

# %%
ckpt_dir = 'abcxo_32_Conv_15Hz' # 250, 1e6
model = 'abcxo_conv_32_15Hz_5channel_v3_9610169491525424_max_10epoch'

# dataset = 'davis_loihi'
# folder_name = 'FromLoihi_ABCXO'

dataset = 'davis'
folder_name = 'ABCOX_simple_fidelity'

total_time = 250
batch_size = 5
#folder_name = 'FromLoihi_ABCXO_15Hz_64_robust'

size = 32

# DATASET
DL = DatasetLoader(dataset=dataset,
                  caching='memory',
                  num_workers=0,
                  batch_size=batch_size,
                  total_time=total_time,
                  sensor_size_to=size,
                  folder_name = folder_name)
train_loader, test_loader, dataset_dict = DL.get_dataloaders()

snn = ModelLoader(model, ckpt_dir, batch_size, device)
# Out:
# [CenterCrop(sensor_size=(240, 180, 2), size=(128, 128)), Downsample(time_factor=1, spatial_factor=0.25, sensor_size=None, target_size=None), ToFrame(sensor_size=(32, 32, 2), time_window=None, event_count=None, n_time_bins=250, n_event_bins=None, overlap=0, include_incomplete=False)]
# Delta t: 1.0 ms
# Instance of <class 'snn_delays.snn_refactored.SNN'> loaded successfully

# %%
snn.debug = True

snn.input2spike_th = 0.5
_, __ = snn.test(test_loader)

quant_bits = 8

quantize_weights(snn, quant_bits, last_layer=True, symmetry=True, print_info=True)
_, pred = snn.test(test_loader)
# Out:
# 5
# Test Loss: 0.04573312774300575
# Avg spk_count per neuron for all 250 time-steps 7946.4800000000005
# Test Accuracy of the model on the test samples: 100.000
#
# ----layers.0.conv.weight----
# n_unique before quantization: 40, 23 pos 17 neg
# max_value before quantization: 0.45959949493408203
# n_unique after quantization: 36, 21 pos 15 neg
# max_value after quantization: 0.4560088813304901, delta_w: 0.014362484216690063
# ----layers.1.conv.weight----
# n_unique before quantization: 400, 282 pos 118 neg
# max_value before quantization: 0.24633574485778809
# n_unique after quantization: 151, 98 pos 52 neg
# max_value after quantization: 0.24441124498844147, delta_w: 0.0019244980067014694
# ----layers.3.linear.weight----
# n_unique before quantization: 3840, 1948 pos 1892 neg
# max_value before quantization: 0.2612723112106323
# n_unique after quantization: 209, 103 pos 105 neg
# max_value after quantization: 0.2592311203479767, delta_w: 0.002041189931333065
# ----layers.4.linear.weight----
# n_unique before quantization: 2304, 1124 pos 1180 neg
# max_value before quantization: 0.3993320167064667
# n_unique after quantization: 196, 94 pos 101 neg
# max_value after quantization: 0.39621224999427795, delta_w: 0.003119781380519271
# ----layers.5.linear.weight----
# n_unique before quantization: 240, 117 pos 123 neg
# max_value before quantization: 0.4977247416973114
# n_unique after quantization: 133, 58 pos 74 neg
# max_value after quantization: 0.49383625388145447, delta_w: 0.0038884745445102453
# 5
# Test Loss: 0.0787353590130806
# Avg spk_count per neuron for all 250 time-steps 7960.92
# Test Accuracy of the model on the test samples: 100.000

# %%
for key in snn.spike_state.keys():
    print(f"{key}: {snn.spike_state[key].shape}")
# Out:
# input: torch.Size([250, 5, 2, 32, 32])
# l0: torch.Size([250, 5, 5, 16, 16])
# l1: torch.Size([250, 5, 5, 4, 4])
# l2: torch.Size([250, 5, 80])
# l3: torch.Size([250, 5, 48])
# l4: torch.Size([250, 5, 48])
# output: torch.Size([250, 5, 5])

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider

spk = snn.spike_state['l0'].detach().cpu().numpy()  # Get spikes from layer 1
sample = 3

def plot_channels(index):
    n_channels = spk.shape[2]  # Number of channels (3rd dimension)
    grid_size = int(np.ceil(np.sqrt(n_channels)))  # Calculate grid size
    
    fig, axes = plt.subplots(grid_size, grid_size, figsize=(8, 8))
    fig.suptitle(f'All Channels at First Dimension Index: {index}', fontsize=16)
    
    # Flatten axes array for easy iteration
    axes = axes.ravel()
    
    for channel in range(n_channels):
        img = spk[index, sample, channel, ...]  # Get channel slice
        axes[channel].imshow(img, cmap='viridis')
        axes[channel].set_title(f'Channel {channel}')
        axes[channel].axis('off')
    
    # Hide unused subplots
    for ax in axes[n_channels:]:
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

# Create interactive slider
interact(
    plot_channels,
    index=IntSlider(
        min=0,
        max=spk.shape[0]-1,
        step=1,
        value=spk.shape[0]//2,
        continuous_update=False,
        description='Index:',
        layout={'width': '500px'}
    )
)
# Out:
# interactive(children=(IntSlider(value=125, continuous_update=False, description='Index:', layout=Layout(width=…
# <function __main__.plot_channels(index)>

# %%
for key in snn.spike_state.keys():
    #if key != 'input':
        spk = snn.spike_state[key].detach().cpu().numpy()
        plt.figure(figsize=(10, 5))
        data = spk[:, sample, ...].reshape((250, -1)).T
        sum_data = int(np.sum(data))
        plt.imshow(data, aspect='auto', interpolation='none')
        plt.title(f'Spikes for {key} at sample {sample}: {sum_data} spikes')
        np.save(f'spikes_{key}_B.npy', data)

# %%
mem = snn.mem_state['l0'].detach().cpu().numpy()
plt.figure(figsize=(10, 5))
data = mem[:, sample, ...].reshape((250, -1)).T
plt.imshow(data, aspect='auto', interpolation='none', vmin=-5.0, vmax=0.3)
plt.title(f'Mems for l0 at sample {sample}: {sum_data} spikes')
plt.colorbar()
np.save(f'mems_l0_B.npy', data)

# %%
plt.plot(data.T[:, 0])
plt.show()
